# %%
! pip freeze
# Out:
# annotated-types==0.7.0
# anyio==4.5.0
# asgiref==3.8.1
# asttokens==2.4.1
# beautifulsoup4==4.12.3
# click==8.1.7
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.0
# cycler==0.12.1
# debugpy==1.8.5
# decorator==5.1.1
# Django==4.2.16
# django-bootstrap-v5==1.0.11
# executing==2.1.0
# fastapi==0.115.0
# fonttools==4.53.1
# h11==0.14.0
# idna==3.10
# ipykernel==6.29.5
# ipython==8.27.0
# jedi==0.19.1
# joblib==1.4.2
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# kiwisolver==1.4.7
# matplotlib==3.9.2
# matplotlib-inline==0.1.7
# nest-asyncio==1.6.0
# numpy==2.1.1
# packaging==24.1
# pandas==2.2.3
# parso==0.8.4
# pillow==10.4.0
# platformdirs==4.3.6
# prompt_toolkit==3.0.47
# psutil==6.0.0
# pure_eval==0.2.3
# pydantic==2.9.2
# pydantic_core==2.23.4
# Pygments==2.18.0
# pyparsing==3.1.4
# python-dateutil==2.9.0.post0
# pytz==2024.2
# pywin32==306
# pyzmq==26.2.0
# scikit-learn==1.5.2
# scipy==1.14.1
# six==1.16.0
# sniffio==1.3.1
# soupsieve==2.6
# sqlparse==0.5.1
# stack-data==0.6.3
# ...

# %%
! pip install numpy
! pip install scikit-learn
! pip install matplotlib
! pip install pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('data/data.csv')
display(data)
# Out:
#     Id         Name  ... Communication Skill  Presentation designing
# 0    1      Melanie  ...                  40                      39
# 1    2       Connor  ...                  21                       5
# 2    3        Karen  ...                  30                      16
# 3    4        Brian  ...                   1                      33
# 4    5          Amy  ...                  21                      14
# 5    6       Victor  ...                   6                      21
# 6    7          Sue  ...                  34                       7
# 7    8      Rebecca  ...                  38                      32
# 8    9         Adam  ...                  29                      28
# 9   10  Christopher  ...                  24                      20
# 10  11       Andrea  ...                   6                      40
# 11  12     Jennifer  ...                   0                       5
# 12  13       Yvonne  ...                  22                      31
# ...

# %%
kmeans = KMeans(n_clusters = 4, random_state = 42)

skillset = ['Coding','Leadership', 'Communication Skill', 'Presentation designing']

kmeans.fit(data[[x for x in skillset]])

data['cluster'] = kmeans.labels_

# %%
display(data)
# Out:
#     Id         Name  ... Presentation designing  cluster
# 0    1      Melanie  ...                     39        2
# 1    2       Connor  ...                      5        2
# 2    3        Karen  ...                     16        2
# 3    4        Brian  ...                     33        2
# 4    5          Amy  ...                     14        2
# 5    6       Victor  ...                     21        2
# 6    7          Sue  ...                      7        2
# 7    8      Rebecca  ...                     32        2
# 8    9         Adam  ...                     28        2
# 9   10  Christopher  ...                     20        2
# 10  11       Andrea  ...                     40        0
# 11  12     Jennifer  ...                      5        0
# 12  13       Yvonne  ...                     31        0
# 13  14        Frank  ...                      8        0
# 14  15         Paul  ...                     37        0
# ...

# %%
# data_0 = data[data['cluster'] == 0]
# data_1 = data[data['cluster'] == 1]
# data_2 = data[data['cluster'] == 2]
# data_3 = data[data['cluster'] == 3]

dataframes = {}

# %%
for x in data['cluster'].unique().tolist():
    dataframes[f'data_{x}'] = data[data['cluster'] == x]

# %%
print(dataframes)
# Out:
# {'data_2':     Id         Name  ... Presentation designing  cluster
# 0    1      Melanie  ...                     39        2
# 1    2       Connor  ...                      5        2
# 2    3        Karen  ...                     16        2
# 3    4        Brian  ...                     33        2
# 4    5          Amy  ...                     14        2
# 5    6       Victor  ...                     21        2
# 6    7          Sue  ...                      7        2
# 7    8      Rebecca  ...                     32        2
# 8    9         Adam  ...                     28        2
# 9   10  Christopher  ...                     20        2
# 38  39        admin  ...                      3        2
#
# [11 rows x 8 columns], 'data_0':     Id      Name  ... Presentation designing  cluster
# 10  11    Andrea  ...                     40        0
# 11  12  Jennifer  ...                      5        0
# 12  13    Yvonne  ...                     31        0
# ...

# %%
display(dataframes['data_0'])
# Out:
#     Id      Name  ... Presentation designing  cluster
# 10  11    Andrea  ...                     40        0
# 11  12  Jennifer  ...                      5        0
# 12  13    Yvonne  ...                     31        0
# 13  14     Frank  ...                      8        0
# 14  15      Paul  ...                     37        0
# 15  16      Adam  ...                     15        0
# 16  17   Lillian  ...                     37        0
# 17  18    Tracey  ...                     34        0
# 18  19      Phil  ...                     20        0
# 19  20    Andrew  ...                      0        0
#
# [10 rows x 8 columns]

# %%
display(dataframes['data_1'])
# Out:
#     Id    Name  ... Presentation designing  cluster
# 20  21   Gavin  ...                     16        1
# 21  22    Rose  ...                     26        1
# 22  23    Leah  ...                     40        1
# 23  24   Irene  ...                      0        1
# 24  25    Lily  ...                      7        1
# 25  26    Mary  ...                      1        1
# 26  27   Sally  ...                      8        1
# 27  28   Kevin  ...                     34        1
# 28  29  Robert  ...                     27        1
# 29  30    Lily  ...                      1        1
#
# [10 rows x 8 columns]

# %%
display(dataframes['data_2'])
# Out:
#     Id         Name  ... Presentation designing  cluster
# 0    1      Melanie  ...                     39        2
# 1    2       Connor  ...                      5        2
# 2    3        Karen  ...                     16        2
# 3    4        Brian  ...                     33        2
# 4    5          Amy  ...                     14        2
# 5    6       Victor  ...                     21        2
# 6    7          Sue  ...                      7        2
# 7    8      Rebecca  ...                     32        2
# 8    9         Adam  ...                     28        2
# 9   10  Christopher  ...                     20        2
# 38  39        admin  ...                      3        2
#
# [11 rows x 8 columns]

# %%
display(dataframes['data_3'])
# Out:
#     Id     Name  ... Presentation designing  cluster
# 30  31    Brian  ...                     79        3
# 31  32    Keith  ...                     74        3
# 32  33      Zoe  ...                     87        3
# 33  34   Audrey  ...                     89        3
# 34  35      Joe  ...                     86        3
# 35  36  Vanessa  ...                     79        3
# 36  37    Karen  ...                    100        3
# 37  38    Chloe  ...                     96        3
#
# [8 rows x 8 columns]

# %%
import random

# %%
smallest_dataset_name = min(dataframes, key=lambda k: len(dataframes[k]))
print(smallest_dataset_name)
# Out:
# data_3

# %%
group = {}
minvalue = len(dataframes[smallest_dataset_name])
print(minvalue)
# Out:
# 8

# %%
for y in range(minvalue):
    singlegroup = []
    for x in dataframes.keys():
        if len(dataframes[x]) > 0:
            item = random.randint(0, len(dataframes[x]) - 1)
            
            selected_item = dataframes[x].iloc[item]
            
            # Assign a random skill from the skills_data list
            # max_value = max([selected_item[x] for x in skillset])

            # mainskill = ''
            # for skill in skillset:
            #     if max_value == int(selected_item[skill]):
            #         mainskill = skill
            #         break

            # # Set the skill in the selected item
            # selected_item['skills'] = mainskill
            
            # Check if the mainskill is not 'Presentation designing'
            # if mainskill != 'Presentation designing':
            #     singlegroup.append(selected_item)
            #     dataframes[x] = dataframes[x].drop(dataframes[x].index[item])

            singlegroup.append(selected_item)
            dataframes[x] = dataframes[x].drop(dataframes[x].index[item])
                

    group[y] = singlegroup

print(group[0])
# Out:
# [Id                                            8
# Name                                    Rebecca
# Email                     testuser8@example.com
# Coding                                       99
# Leadership                                    2
# Communication Skill                          38
# Presentation designing                       32
# cluster                                       2
# Name: 7, dtype: object, Id                                            16
# Name                                        Adam
# Email                     testuser16@example.com
# Coding                                         6
# Leadership                                    76
# Communication Skill                           39
# Presentation designing                        15
# cluster                                        0
# Name: 15, dtype: object, Id                                            24
# Name                                       Irene
# ...

# %%
print(len(group))
# Out:
# 8

# %%
display(group)
# Out:
# {0: [Id                                            8
#   Name                                    Rebecca
#   Email                     testuser8@example.com
#   Coding                                       99
#   Leadership                                    2
#   Communication Skill                          38
#   Presentation designing                       32
#   cluster                                       2
#   Name: 7, dtype: object,
#   Id                                            16
#   Name                                        Adam
#   Email                     testuser16@example.com
#   Coding                                         6
#   Leadership                                    76
#   Communication Skill                           39
#   Presentation designing                        15
#   cluster                                        0
#   Name: 15, dtype: object,
#   Id                                            24
# ...

# %%
for x in group.keys():
    display(pd.DataFrame(group[x]))
# Out:
#     Id     Name  ... Presentation designing  cluster
# 7    8  Rebecca  ...                     32        2
# 15  16     Adam  ...                     15        0
# 23  24    Irene  ...                      0        1
# 32  33      Zoe  ...                     87        3
#
# [4 rows x 8 columns]
#     Id      Name  ... Presentation designing  cluster
# 8    9      Adam  ...                     28        2
# 11  12  Jennifer  ...                      5        0
# 26  27     Sally  ...                      8        1
# 33  34    Audrey  ...                     89        3
#
# [4 rows x 8 columns]
#     Id     Name  ... Presentation designing  cluster
# 1    2   Connor  ...                      5        2
# 16  17  Lillian  ...                     37        0
# 20  21    Gavin  ...                     16        1
# 31  32    Keith  ...                     74        3
#
# [4 rows x 8 columns]
#     Id     Name  ... Presentation designing  cluster
# ...

# %%
display(dataframes['data_0'])
# Out:
#     Id    Name  ... Presentation designing  cluster
# 10  11  Andrea  ...                     40        0
# 19  20  Andrew  ...                      0        0
#
# [2 rows x 8 columns]

# %%
display(dataframes['data_1'])
# Out:
#     Id    Name  ... Presentation designing  cluster
# 22  23    Leah  ...                     40        1
# 28  29  Robert  ...                     27        1
#
# [2 rows x 8 columns]

# %%
display(dataframes['data_2'])
# Out:
#    Id         Name  ... Presentation designing  cluster
# 2   3        Karen  ...                     16        2
# 6   7          Sue  ...                      7        2
# 9  10  Christopher  ...                     20        2
#
# [3 rows x 8 columns]

# %%
display(dataframes['data_3'])
# Out:
# Empty DataFrame
# Columns: [Id, Name, Email, Coding, Leadership, Communication Skill, Presentation designing, cluster]
# Index: []

# %%
left_out = pd.concat([dataframes['data_0'], dataframes['data_1'], dataframes['data_2'], dataframes['data_3']], axis=0, ignore_index=True)
display(left_out)
# Out:
#    Id         Name  ... Presentation designing  cluster
# 0  11       Andrea  ...                     40        0
# 1  20       Andrew  ...                      0        0
# 2  23         Leah  ...                     40        1
# 3  29       Robert  ...                     27        1
# 4   3        Karen  ...                     16        2
# 5   7          Sue  ...                      7        2
# 6  10  Christopher  ...                     20        2
#
# [7 rows x 8 columns]

# %%
display(left_out.keys())
# Out:
# Index(['Id', 'Name', 'Email', 'Coding', 'Leadership', 'Communication Skill',
#        'Presentation designing', 'cluster'],
#       dtype='object')

# %%
# Shuffle the DataFrame to randomize the student order
df = left_out.sample(frac=1).reset_index(drop=True)

# Function to form groups with an attempt to diversify clusters
def form_groups(df, group_size):
    groups = []
    current_group = []
    used_clusters = set()

    for i, row in df.iterrows():
        cluster = row['cluster']
        
        # If the group is not full, try to add students from a different cluster
        if len(current_group) < group_size:
            if cluster not in used_clusters or len(used_clusters) == 0:
                current_group.append(row)
                used_clusters.add(cluster)
            else:
                # Add to group even if cluster is repeated if needed to fill the group
                current_group.append(row)
        
        # If group is full or at the last student, finalize the group
        if len(current_group) == group_size or i == len(df) - 1:
            groups.append(pd.DataFrame(current_group))
            current_group = []
            used_clusters = set()

    # Return the formed groups
    return groups

# Form groups of 4  
groups = form_groups(df, 4)

# Display the grouped DataFrame
print(groups)
# Out:
# [   Id    Name  ... Presentation designing  cluster
# 0  23    Leah  ...                     40        1
# 1  11  Andrea  ...                     40        0
# 2  29  Robert  ...                     27        1
# 3   7     Sue  ...                      7        2
#
# [4 rows x 8 columns],    Id         Name  ... Presentation designing  cluster
# 4   3        Karen  ...                     16        2
# 5  20       Andrew  ...                      0        0
# 6  10  Christopher  ...                     20        2
#
# [3 rows x 8 columns]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
print(data)
# Out:
#     Id         Name  ... Presentation designing  cluster
# 0    1      Melanie  ...                     39        2
# 1    2       Connor  ...                      5        2
# 2    3        Karen  ...                     16        2
# 3    4        Brian  ...                     33        2
# 4    5          Amy  ...                     14        2
# 5    6       Victor  ...                     21        2
# 6    7          Sue  ...                      7        2
# 7    8      Rebecca  ...                     32        2
# 8    9         Adam  ...                     28        2
# 9   10  Christopher  ...                     20        2
# 10  11       Andrea  ...                     40        0
# 11  12     Jennifer  ...                      5        0
# 12  13       Yvonne  ...                     31        0
# 13  14        Frank  ...                      8        0
# 14  15         Paul  ...                     37        0
# ...

# %%
plt.scatter(data['Coding'], data['Leadership'])
plt.xlabel('coding')
plt.ylabel('leadership')
# Out:
# Text(0, 0.5, 'leadership')

# %%
plt.scatter(data['Leadership'],data['Communication Skill'])

# %%
plt.scatter(data['Communication Skill'], data['Presentation designing'])

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data['Coding'], data['Leadership'], data['Communication Skill'], cmap='viridis')
ax.set_xlabel('Coding')
ax.set_ylabel('Leadership')
ax.set_zlabel('Communication Skill')

# Show plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20276\3961283778.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(data['Coding'], data['Leadership'], data['Communication Skill'], cmap='viridis')

# %%
import matplotlib.pyplot as plt
import numpy as np
import io
import base64

# Skills and their strength levels
skills = ['Coding', 'Leadership', 'Communication', 'Presentation designing']
strengths = [83, 21, 8, 98]

# --- Create Radar Chart ---
# Define the skill and strength data
categories = skills
values = strengths
N = len(categories)

# What will be the angle of each axis in the radar chart (we divide the plot / number of variables)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]  # Complete the loop by connecting the last value to the first

# Strength levels need to be repeated to complete the loop
values += values[:1]

# Initialize the radar chart
plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)

# Draw one axis per skill and label it
plt.xticks(angles[:-1], categories)

# Plot the data
ax.plot(angles, values, linewidth=1, linestyle='solid')

# Fill the area under the plot
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.title('Strength-Skill Radar Chart')

# # Save the radar chart to a bytes buffer
# buf_radar = io.BytesIO()
# plt.savefig(buf_radar, format='png')
# buf_radar.seek(0)

# # Convert the buffer contents to a base64 string for the radar chart
# img_data_radar = base64.b64encode(buf_radar.getvalue()).decode('utf-8')
# Out:
# Text(0.5, 1.0, 'Strength-Skill Radar Chart')
